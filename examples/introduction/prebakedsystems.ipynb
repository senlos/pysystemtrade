# %%
# %matplotlib inline

# %%
run basesystem.py
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# OSError: File `'basesystem.py'` not found.
#
# The above exception was the direct cause of the following exception:
#
# Exception                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 get_ipython().run_line_magic('run', 'basesystem.py')
#
# Exception: File `'basesystem.py'` not found.
